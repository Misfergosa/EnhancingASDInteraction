# %% [markdown]
# *GROUP NAMES*
#
#  Abdullah Althobaiti
#
#  Abdulaziz Alhazazi
#
#  Fahad Alrashedi
#
#  Misfer Algosa

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.8/778.8 kB 4.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 29.6MB/s]

# %%
#"C:\Users\xzyad\Downloads\Car Truck finder.v2i.yolov8.zip"
# !unzip '/content/Rock Paper Scissors.v44-rock-paper-scissors_raw-images.yolov8.zip'
# Out:
# Archive:  /content/Rock Paper Scissors.v44-rock-paper-scissors_raw-images.yolov8.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/Cool-Video-of-Ocean-Fish-Swimming_mp4-12_jpg.rf.c42aaf48a71c07bd20f047a10ef9add7.jpg
#  extracting: test/images/Cool-Video-of-Ocean-Fish-Swimming_mp4-8_jpg.rf.71ae8b64db1364bda1ace0dedae08284.jpg
#  extracting: test/images/Screen-Shot-2021-05-12-at-3-28-30-PM_png.rf.30cf69de16ee49fb13602b3d3961815d.jpg
#  extracting: test/images/egohands-public-1620849842064_png.rf.4c2b573a94e4360b9a5de54e5a5f7d5e.jpg
#  extracting: test/images/egohands-public-1620849844997_png.rf.75d751bd0fd9292d096bdc890924cacc.jpg
#  extracting: test/images/egohands-public-1620849847487_png.rf.cac65f49478a0af5a91fc30a2a602648.jpg
#  extracting: test/images/egohands-public-1620849871605_png.rf.aa5b206fc211de05f216650a4cc35136.jpg
# ...

# %%
results = model.train(


   data='/content/data.yaml',
   imgsz=640,
   epochs=1,
   batch=32,
   name='yolov8n_custom_flood')
# Out:
# Ultralytics YOLOv8.2.25 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model = YOLO(model='runs/detect/yolov8n_custom_flood/weights/best.pt')
 # load a custom model

# Validate the model
results = model.val()
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/valid/labels.cache... 154 images, 49 backgrounds, 0 corrupt: 100%|██████████| 154/154 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:16<00:00,  1.65s/it]
#                    all        154        105       0.96      0.916      0.949      0.625
#                  Paper        154         38          1      0.909      0.969      0.597
#                   Rock        154         36      0.908          1      0.994      0.659
#               Scissors        154         31      0.972      0.839      0.882      0.619
# Speed: 1.2ms preprocess, 86.6ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/val

# %%
results = model('/content/scissors.jpg')  # predict on an image
# Out:
# image 1/1 /content/scissors.jpg: 480x640 1 Rock, 1 Scissors, 135.7ms
# Speed: 2.6ms preprocess, 135.7ms inference, 47.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
from IPython.display import display, Image

# %%
# %cd {HOME}
Image(filename='/content/runs/detect/yolov8n_custom_flood/results.png', height=600)
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content

# %%
Image(filename='/content/runs/detect/yolov8n_custom_flood/train_batch1.jpg', height=800)

# %%
# !pip install opencv-python

# %%
import cv2
model = YOLO("/content/yolov8n.pt")
names = model.names

cap = cv2.VideoCapture(0)
